# %% [markdown]
# # **Assignment 2:**
#
#  Implement POS tagging on a text corpus using an NLP library (like NLTK or SpaCy).
# Analyze the grammatical structure of sentences using syntactic/dependency parsing.

# %% [markdown]
# “POS tagging was performed using spaCy’s pre-trained English model to identify grammatical categories of words. Dependency parsing was applied to analyze syntactic relationships between tokens. The dependency tree visualization helped in understanding subject–predicate relationships and sentence structure.”

# %% [markdown]
# ## **Loading the Text Corpus**

# %%
text = """Artificial Intelligence (AI) has emerged as one of the most transformative technologies of the twenty-first century. From simple rule-based systems to complex deep learning architectures, AI has evolved rapidly and is now deeply integrated into many aspects of daily life. Its influence can be seen across industries such as healthcare, education, finance, transportation, and entertainment. As AI systems continue to grow in capability and adoption, they are reshaping how humans work, communicate, and make decisions.

At its core, artificial intelligence refers to the ability of machines to simulate human intelligence. This includes learning from data, recognizing patterns, understanding language, and making decisions with minimal human intervention. Early AI systems were limited in scope and required explicit programming. However, modern AI relies heavily on machine learning and deep learning techniques, enabling systems to improve automatically through experience. The availability of large datasets, increased computational power, and advanced algorithms has accelerated this progress significantly.

One of the most impactful applications of AI is in healthcare. AI-powered systems are now used to assist doctors in diagnosing diseases, predicting patient outcomes, and personalizing treatment plans. For example, machine learning models can analyze medical images such as X-rays and MRIs with high accuracy, often matching or exceeding human performance. AI also plays a crucial role in drug discovery by analyzing chemical compounds and predicting their effectiveness, reducing both time and cost. Despite these benefits, concerns remain regarding data privacy, bias in medical datasets, and the need for human oversight in critical healthcare decisions.

In the field of education, AI is transforming traditional learning methods. Intelligent tutoring systems can adapt content based on a student’s learning pace, strengths, and weaknesses. Online learning platforms use recommendation algorithms to suggest courses and resources tailored to individual needs. Automated grading systems help educators save time while providing consistent evaluation. However, over-reliance on AI in education raises questions about reduced human interaction, unequal access to technology, and the potential loss of critical thinking skills if students depend too heavily on automated assistance.

Data privacy and security are also critical issues in the AI era. AI systems rely on vast amounts of data, much of which is personal or sensitive. Ensuring that data is collected, stored, and used responsibly is essential to maintaining public trust. Governments and organizations worldwide are developing regulations and ethical guidelines to govern AI development and deployment. These efforts aim to balance innovation with responsibility, ensuring that AI benefits society as a whole.

Looking ahead, the future of artificial intelligence will depend on how humans choose to design, regulate, and interact with these systems. Collaboration between technologists, policymakers, educators, and ethicists is necessary to address the challenges and maximize the benefits of AI. Rather than replacing humans, AI has the potential to augment human capabilities, enabling better decision-making, creativity, and problem-solving.

In conclusion, artificial intelligence is a powerful tool that is reshaping modern society in profound ways. Its applications span multiple domains, offering solutions to complex problems while also introducing new risks and ethical dilemmas. Understanding AI’s capabilities and limitations is essential for responsible use. As AI continues to evolve, its impact will be determined not only by technological advancements but also by the values and choices of the people who develop and deploy it.
"""

# %% [markdown]
# ## **Loading spaCy Model**

# %%
# Importing Required Libraries
import spacy
nlp = spacy.load('en_core_web_sm')

# %%
doc = nlp(text)

# %%
doc
# Out:
# Artificial Intelligence (AI) has emerged as one of the most transformative technologies of the twenty-first century. From simple rule-based systems to complex deep learning architectures, AI has evolved rapidly and is now deeply integrated into many aspects of daily life. Its influence can be seen across industries such as healthcare, education, finance, transportation, and entertainment. As AI systems continue to grow in capability and adoption, they are reshaping how humans work, communicate, and make decisions.
#
# At its core, artificial intelligence refers to the ability of machines to simulate human intelligence. This includes learning from data, recognizing patterns, understanding language, and making decisions with minimal human intervention. Early AI systems were limited in scope and required explicit programming. However, modern AI relies heavily on machine learning and deep learning techniques, enabling systems to improve automatically through experience. The availability of large datasets, increased computational power, and advanced algorithms has accelerated this progress significantly.
#
# One of the most impactful applications of AI is in healthcare. AI-powered systems are now used to assist doctors in diagnosing diseases, predicting patient outcomes, and personalizing treatment plans. For example, machine learning models can analyze medical images such as X-rays and MRIs with high accuracy, often matching or exceeding human performance. AI also plays a crucial role in drug discovery by analyzing chemical compounds and predicting their effectiveness, reducing both time and cost. Despite these benefits, concerns remain regarding data privacy, bias in medical datasets, and the need for human oversight in critical healthcare decisions.
#
# In the field of education, AI is transforming traditional learning methods. Intelligent tutoring systems can adapt content based on a student’s learning pace, strengths, and weaknesses. Online learning platforms use recommendation algorithms to suggest courses and resources tailored to individual needs. Automated grading systems help educators save time while providing consistent evaluation. However, over-reliance on AI in education raises questions about reduced human interaction, unequal access to technology, and the potential loss of critical thinking skills if students depend too heavily on automated assistance.
#
# Data privacy and security are also critical issues in the AI era. AI systems rely on vast amounts of data, much of which is personal or sensitive. Ensuring that data is collected, stored, and used responsibly is essential to maintaining public trust. Governments and organizations worldwide are developing regulations and ethical guidelines to govern AI development and deployment. These efforts aim to balance innovation with responsibility, ensuring that AI benefits society as a whole.
#
# Looking ahead, the future of artificial intelligence will depend on how humans choose to design, regulate, and interact with these systems. Collaboration between technologists, policymakers, educators, and ethicists is necessary to address the challenges and maximize the benefits of AI. Rather than replacing humans, AI has the potential to augment human capabilities, enabling better decision-making, creativity, and problem-solving.
#
# In conclusion, artificial intelligence is a powerful tool that is reshaping modern society in profound ways. Its applications span multiple domains, offering solutions to complex problems while also introducing new risks and ethical dilemmas. Understanding AI’s capabilities and limitations is essential for responsible use. As AI continues to evolve, its impact will be determined not only by technological advancements but also by the values and choices of the people who develop and deploy it.

# %% [markdown]
# ## **POS Tagging Implementation**

# %%
for token in doc:
    print(f"{token.text:<15} {token.pos_:<10} {token.tag_:<10} {token.dep_}")
# Out:
# Artificial      PROPN      NNP        compound
# Intelligence    PROPN      NNP        nsubj
# (               PUNCT      -LRB-      punct
# AI              PROPN      NNP        appos
# )               PUNCT      -RRB-      punct
# has             AUX        VBZ        aux
# emerged         VERB       VBN        ROOT
# as              ADP        IN         prep
# one             NUM        CD         pobj
# of              ADP        IN         prep
# the             DET        DT         det
# most            ADV        RBS        advmod
# transformative  ADJ        JJ         amod
# technologies    NOUN       NNS        pobj
# of              ADP        IN         prep
# the             DET        DT         det
# twenty          NUM        CD         advmod
# -               PUNCT      HYPH       punct
# first           ADJ        JJ         amod
# century         NOUN       NN         pobj
# .               PUNCT      .          punct
# From            ADP        IN         prep
# simple          ADJ        JJ         amod
# rule            NOUN       NN         npadvmod
# -               PUNCT      HYPH       punct
# based           VERB       VBN        amod
# systems         NOUN       NNS        pobj
# to              PART       TO         prep
# complex         ADJ        JJ         amod
# deep            ADJ        JJ         amod
# learning        NOUN       NN         pobj
# architectures   VERB       VBZ        pobj
# ,               PUNCT      ,          punct
# AI              PROPN      NNP        nsubj
# has             AUX        VBZ        aux
# evolved         VERB       VBN        ROOT
# rapidly         ADV        RB         advmod
# and             CCONJ      CC         cc
# is              AUX        VBZ        auxpass
# now             ADV        RB         advmod
# deeply          ADV        RB         advmod
# integrated      VERB       VBN        conj
# into            ADP        IN         prep
# many            ADJ        JJ         amod
# aspects         NOUN       NNS        pobj
# of              ADP        IN         prep
# daily           ADJ        JJ         amod
# life            NOUN       NN         pobj
# .               PUNCT      .          punct
# Its             PRON       PRP$       poss
# influence       NOUN       NN         nsubjpass
# can             AUX        MD         aux
# be              AUX        VB         auxpass
# seen            VERB       VBN        ROOT
# across          ADP        IN         prep
# industries      NOUN       NNS        pobj
# such            ADJ        JJ         amod
# as              ADP        IN         prep
# healthcare      NOUN       NN         pobj
# ,               PUNCT      ,          punct
# education       NOUN       NN         conj
# ,               PUNCT      ,          punct
# finance         NOUN       NN         conj
# ,               PUNCT      ,          punct
# transportation  NOUN       NN         conj
# ,               PUNCT      ,          punct
# and             CCONJ      CC         cc
# entertainment   NOUN       NN         conj
# .               PUNCT      .          punct
# As              SCONJ      IN         mark
# AI              PROPN      NNP        compound
# systems         NOUN       NNS        nsubj
# continue        VERB       VBP        advcl
# to              PART       TO         aux
# grow            VERB       VB         xcomp
# in              ADP        IN         prep
# capability      NOUN       NN         pobj
# and             CCONJ      CC         cc
# adoption        NOUN       NN         conj
# ,               PUNCT      ,          punct
# they            PRON       PRP        nsubj
# are             AUX        VBP        aux
# reshaping       VERB       VBG        ROOT
# how             SCONJ      WRB        advmod
# humans          NOUN       NNS        nsubj
# work            VERB       VBP        ccomp
# ,               PUNCT      ,          punct
# communicate     VERB       VBP        conj
# ,               PUNCT      ,          punct
# and             CCONJ      CC         cc
# make            VERB       VB         conj
# decisions       NOUN       NNS        dobj
# .               PUNCT      .          punct
#
#
#               SPACE      _SP        dep
# At              ADP        IN         prep
# its             PRON       PRP$       poss
# core            NOUN       NN         pobj
# ,               PUNCT      ,          punct
# artificial      ADJ        JJ         amod
# intelligence    NOUN       NN         nsubj
# refers          VERB       VBZ        ROOT
# to              ADP        IN         prep
# the             DET        DT         det
# ability         NOUN       NN         pobj
# of              ADP        IN         prep
# machines        NOUN       NNS        pobj
# to              PART       TO         aux
# simulate        VERB       VB         acl
# human           ADJ        JJ         amod
# intelligence    NOUN       NN         dobj
# .               PUNCT      .          punct
# This            PRON       DT         nsubj
# includes        VERB       VBZ        ROOT
# learning        VERB       VBG        xcomp
# from            ADP        IN         prep
# data            NOUN       NNS        pobj
# ,               PUNCT      ,          punct
# recognizing     VERB       VBG        advcl
# patterns        NOUN       NNS        dobj
# ,               PUNCT      ,          punct
# understanding   VERB       VBG        acl
# language        NOUN       NN         dobj
# ,               PUNCT      ,          punct
# and             CCONJ      CC         cc
# making          VERB       VBG        conj
# decisions       NOUN       NNS        dobj
# with            ADP        IN         prep
# minimal         ADJ        JJ         amod
# human           ADJ        JJ         amod
# intervention    NOUN       NN         pobj
# .               PUNCT      .          punct
# Early           ADJ        JJ         amod
# AI              PROPN      NNP        compound
# systems         NOUN       NNS        nsubjpass
# were            AUX        VBD        auxpass
# limited         VERB       VBN        ROOT
# in              ADP        IN         prep
# scope           NOUN       NN         pobj
# and             CCONJ      CC         cc
# required        VERB       VBD        conj
# explicit        ADJ        JJ         amod
# programming     NOUN       NN         dobj
# .               PUNCT      .          punct
# However         ADV        RB         advmod
# ,               PUNCT      ,          punct
# modern          ADJ        JJ         amod
# AI              PROPN      NNP        nsubj
# relies          VERB       VBZ        ROOT
# heavily         ADV        RB         advmod
# on              ADP        IN         prep
# machine         NOUN       NN         compound
# learning        NOUN       NN         pobj
# and             CCONJ      CC         cc
# deep            ADJ        JJ         amod
# learning        NOUN       NN         compound
# techniques      NOUN       NNS        conj
# ,               PUNCT      ,          punct
# enabling        VERB       VBG        advcl
# systems         NOUN       NNS        dobj
# to              PART       TO         aux
# improve         VERB       VB         xcomp
# automatically   ADV        RB         advmod
# through         ADP        IN         prep
# experience      NOUN       NN         pobj
# .               PUNCT      .          punct
# The             DET        DT         det
# availability    NOUN       NN         nsubj
# of              ADP        IN         prep
# large           ADJ        JJ         amod
# datasets        NOUN       NNS        pobj
# ,               PUNCT      ,          punct
# increased       VERB       VBD        ROOT
# computational   ADJ        JJ         amod
# power           NOUN       NN         dobj
# ,               PUNCT      ,          punct
# and             CCONJ      CC         cc
# advanced        ADJ        JJ         amod
# algorithms      NOUN       NNS        nsubj
# has             AUX        VBZ        aux
# accelerated     VERB       VBN        conj
# this            DET        DT         det
# progress        NOUN       NN         dobj
# significantly   ADV        RB         advmod
# .               PUNCT      .          punct
#
#
#               SPACE      _SP        dep
# One             NUM        CD         nsubj
# of              ADP        IN         prep
# the             DET        DT         det
# most            ADV        RBS        advmod
# impactful       ADJ        JJ         amod
# applications    NOUN       NNS        pobj
# of              ADP        IN         prep
# AI              PROPN      NNP        pobj
# is              AUX        VBZ        ROOT
# in              ADP        IN         prep
# healthcare      NOUN       NN         pobj
# .               PUNCT      .          punct
# AI              PROPN      NNP        npadvmod
# -               PUNCT      HYPH       punct
# powered         VERB       VBN        amod
# systems         NOUN       NNS        nsubjpass
# are             AUX        VBP        auxpass
# now             ADV        RB         advmod
# used            VERB       VBN        ROOT
# to              PART       TO         aux
# assist          VERB       VB         xcomp
# doctors         NOUN       NNS        dobj
# in              ADP        IN         prep
# diagnosing      VERB       VBG        pcomp
# diseases        NOUN       NNS        dobj
# ,               PUNCT      ,          punct
# predicting      VERB       VBG        advcl
# patient         ADJ        JJ         amod
# outcomes        NOUN       NNS        dobj
# ,               PUNCT      ,          punct
# and             CCONJ      CC         cc
# personalizing   VERB       VBG        conj
# treatment       NOUN       NN         compound
# plans           NOUN       NNS        dobj
# .               PUNCT      .          punct
# For             ADP        IN         prep
# example         NOUN       NN         pobj
# ,               PUNCT      ,          punct
# machine         NOUN       NN         compound
# learning        NOUN       NN         compound
# models          NOUN       NNS        nsubj
# can             AUX        MD         aux
# analyze         VERB       VB         ROOT
# medical         ADJ        JJ         amod
# images          NOUN       NNS        dobj
# such            ADJ        JJ         amod
# as              ADP        IN         prep
# X               NOUN       NNS        pobj
# -               NOUN       NNS        pobj
# rays            NOUN       NNS        pobj
# and             CCONJ      CC         cc
# MRIs            PROPN      NNPS       conj
# with            ADP        IN         prep
# high            ADJ        JJ         amod
# accuracy        NOUN       NN         pobj
# ,               PUNCT      ,          punct
# often           ADV        RB         advmod
# matching        VERB       VBG        advcl
# or              CCONJ      CC         cc
# exceeding       VERB       VBG        conj
# human           ADJ        JJ         amod
# performance     NOUN       NN         dobj
# .               PUNCT      .          punct
# AI              PROPN      NNP        nsubj
# also            ADV        RB         advmod
# plays           VERB       VBZ        ROOT
# a               DET        DT         det
# crucial         ADJ        JJ         amod
# role            NOUN       NN         dobj
# in              ADP        IN         prep
# drug            NOUN       NN         compound
# discovery       NOUN       NN         pobj
# by              ADP        IN         prep
# analyzing       VERB       VBG        pcomp
# chemical        ADJ        JJ         compound
# compounds       NOUN       NNS        dobj
# and             CCONJ      CC         cc
# predicting      VERB       VBG        conj
# their           PRON       PRP$       poss
# effectiveness   NOUN       NN         dobj
# ,               PUNCT      ,          punct
# reducing        VERB       VBG        advcl
# both            DET        DT         det
# time            NOUN       NN         dobj
# and             CCONJ      CC         cc
# cost            NOUN       NN         conj
# .               PUNCT      .          punct
# Despite         SCONJ      IN         prep
# these           DET        DT         det
# benefits        NOUN       NNS        pobj
# ,               PUNCT      ,          punct
# concerns        NOUN       NNS        nsubj
# remain          VERB       VBP        ROOT
# regarding       VERB       VBG        prep
# data            NOUN       NNS        compound
# privacy         NOUN       NN         pobj
# ,               PUNCT      ,          punct
# bias            NOUN       NN         conj
# in              ADP        IN         prep
# medical         ADJ        JJ         amod
# datasets        NOUN       NNS        pobj
# ,               PUNCT      ,          punct
# and             CCONJ      CC         cc
# the             DET        DT         det
# need            NOUN       NN         conj
# for             ADP        IN         prep
# human           ADJ        JJ         amod
# oversight       NOUN       NN         pobj
# in              ADP        IN         prep
# critical        ADJ        JJ         amod
# healthcare      NOUN       NN         compound
# decisions       NOUN       NNS        pobj
# .               PUNCT      .          punct
#
#
#               SPACE      _SP        dep
# In              ADP        IN         prep
# the             DET        DT         det
# field           NOUN       NN         pobj
# of              ADP        IN         prep
# education       NOUN       NN         pobj
# ,               PUNCT      ,          punct
# AI              PROPN      NNP        nsubj
# is              AUX        VBZ        aux
# transforming    VERB       VBG        ROOT
# traditional     ADJ        JJ         amod
# learning        NOUN       NN         compound
# methods         NOUN       NNS        dobj
# .               PUNCT      .          punct
# Intelligent     ADJ        JJ         amod
# tutoring        NOUN       NN         compound
# systems         NOUN       NNS        nsubj
# can             AUX        MD         aux
# adapt           VERB       VB         ROOT
# content         NOUN       NN         dobj
# based           VERB       VBN        prep
# on              ADP        IN         prep
# a               DET        DT         det
# student         NOUN       NN         npadvmod
# ’s              PART       POS        case
# learning        VERB       VBG        compound
# pace            NOUN       NN         pobj
# ,               PUNCT      ,          punct
# strengths       NOUN       NNS        conj
# ,               PUNCT      ,          punct
# and             CCONJ      CC         cc
# weaknesses      NOUN       NNS        conj
# .               PUNCT      .          punct
# Online          ADJ        JJ         amod
# learning        NOUN       NN         compound
# platforms       NOUN       NNS        nsubj
# use             VERB       VBP        ROOT
# recommendation  NOUN       NN         compound
# algorithms      NOUN       NNS        dobj
# to              PART       TO         aux
# suggest         VERB       VB         xcomp
# courses         NOUN       NNS        dobj
# and             CCONJ      CC         cc
# resources       NOUN       NNS        conj
# tailored        VERB       VBN        acl
# to              ADP        IN         prep
# individual      ADJ        JJ         amod
# needs           NOUN       NNS        pobj
# .               PUNCT      .          punct
# Automated       ADJ        JJ         amod
# grading         NOUN       NN         compound
# systems         NOUN       NNS        nsubj
# help            VERB       VBP        ROOT
# educators       NOUN       NNS        nsubj
# save            VERB       VB         ccomp
# time            NOUN       NN         dobj
# while           SCONJ      IN         mark
# providing       VERB       VBG        advcl
# consistent      ADJ        JJ         amod
# evaluation      NOUN       NN         dobj
# .               PUNCT      .          punct
# However         ADV        RB         advmod
# ,               PUNCT      ,          punct
# over            ADP        IN         nsubj
# -               PUNCT      HYPH       punct
# reliance        NOUN       NN         pobj
# on              ADP        IN         prep
# AI              PROPN      NNP        pobj
# in              ADP        IN         prep
# education       NOUN       NN         pobj
# raises          VERB       VBZ        ROOT
# questions       NOUN       NNS        dobj
# about           ADP        IN         prep
# reduced         VERB       VBN        amod
# human           ADJ        JJ         amod
# interaction     NOUN       NN         pobj
# ,               PUNCT      ,          punct
# unequal         ADJ        JJ         amod
# access          NOUN       NN         prep
# to              ADP        IN         prep
# technology      NOUN       NN         pobj
# ,               PUNCT      ,          punct
# and             CCONJ      CC         cc
# the             DET        DT         det
# potential       ADJ        JJ         amod
# loss            NOUN       NN         conj
# of              ADP        IN         prep
# critical        ADJ        JJ         amod
# thinking        NOUN       NN         compound
# skills          NOUN       NNS        pobj
# if              SCONJ      IN         mark
# students        NOUN       NNS        nsubj
# depend          VERB       VBP        advcl
# too             ADV        RB         advmod
# heavily         ADV        RB         advmod
# on              ADP        IN         prep
# automated       ADJ        JJ         amod
# assistance      NOUN       NN         pobj
# .               PUNCT      .          punct
#
#
#               SPACE      _SP        dep
# Data            NOUN       NNS        compound
# privacy         NOUN       NN         nsubj
# and             CCONJ      CC         cc
# security        NOUN       NN         conj
# are             AUX        VBP        ROOT
# also            ADV        RB         advmod
# critical        ADJ        JJ         amod
# issues          NOUN       NNS        attr
# in              ADP        IN         prep
# the             DET        DT         det
# AI              PROPN      NNP        compound
# era             NOUN       NN         pobj
# .               PUNCT      .          punct
# AI              PROPN      NNP        compound
# systems         NOUN       NNS        nsubj
# rely            VERB       VBP        ROOT
# on              ADP        IN         prep
# vast            ADJ        JJ         amod
# amounts         NOUN       NNS        pobj
# of              ADP        IN         prep
# data            NOUN       NNS        pobj
# ,               PUNCT      ,          punct
# much            ADJ        JJ         nsubj
# of              ADP        IN         prep
# which           PRON       WDT        pobj
# is              AUX        VBZ        relcl
# personal        ADJ        JJ         acomp
# or              CCONJ      CC         cc
# sensitive       ADJ        JJ         conj
# .               PUNCT      .          punct
# Ensuring        VERB       VBG        advcl
# that            SCONJ      IN         mark
# data            NOUN       NNS        nsubjpass
# is              AUX        VBZ        auxpass
# collected       VERB       VBN        ccomp
# ,               PUNCT      ,          punct
# stored          VERB       VBN        conj
# ,               PUNCT      ,          punct
# and             CCONJ      CC         cc
# used            VERB       VBN        csubj
# responsibly     ADV        RB         advmod
# is              AUX        VBZ        ROOT
# essential       ADJ        JJ         acomp
# to              ADP        IN         prep
# maintaining     VERB       VBG        pcomp
# public          ADJ        JJ         amod
# trust           NOUN       NN         dobj
# .               PUNCT      .          punct
# Governments     NOUN       NNS        nsubj
# and             CCONJ      CC         cc
# organizations   NOUN       NNS        conj
# worldwide       ADV        RB         advmod
# are             AUX        VBP        aux
# developing      VERB       VBG        ROOT
# regulations     NOUN       NNS        dobj
# and             CCONJ      CC         cc
# ethical         ADJ        JJ         amod
# guidelines      NOUN       NNS        conj
# to              PART       TO         aux
# govern          VERB       VB         acl
# AI              PROPN      NNP        compound
# development     NOUN       NN         dobj
# and             CCONJ      CC         cc
# deployment      NOUN       NN         conj
# .               PUNCT      .          punct
# These           DET        DT         det
# efforts         NOUN       NNS        nsubj
# aim             VERB       VBP        ROOT
# to              PART       TO         aux
# balance         VERB       VB         xcomp
# innovation      NOUN       NN         dobj
# with            ADP        IN         prep
# responsibility  NOUN       NN         pobj
# ,               PUNCT      ,          punct
# ensuring        VERB       VBG        advcl
# that            SCONJ      IN         mark
# AI              PROPN      NNP        nsubj
# benefits        VERB       VBZ        compound
# society         NOUN       NN         dobj
# as              ADP        IN         prep
# a               DET        DT         det
# whole           NOUN       NN         pobj
# .               PUNCT      .          punct
#
#
#               SPACE      _SP        dep
# Looking         VERB       VBG        advcl
# ahead           ADV        RB         advmod
# ,               PUNCT      ,          punct
# the             DET        DT         det
# future          NOUN       NN         nsubj
# of              ADP        IN         prep
# artificial      ADJ        JJ         amod
# intelligence    NOUN       NN         pobj
# will            AUX        MD         aux
# depend          VERB       VB         ROOT
# on              ADP        IN         prep
# how             SCONJ      WRB        advmod
# humans          NOUN       NNS        nsubj
# choose          VERB       VBP        pcomp
# to              PART       TO         aux
# design          VERB       VB         xcomp
# ,               PUNCT      ,          punct
# regulate        VERB       VBP        conj
# ,               PUNCT      ,          punct
# and             CCONJ      CC         cc
# interact        VERB       VB         conj
# with            ADP        IN         prep
# these           DET        DT         det
# systems         NOUN       NNS        pobj
# .               PUNCT      .          punct
# Collaboration   NOUN       NN         nsubj
# between         ADP        IN         prep
# technologists   NOUN       NNS        pobj
# ,               PUNCT      ,          punct
# policymakers    NOUN       NNS        conj
# ,               PUNCT      ,          punct
# educators       NOUN       NNS        conj
# ,               PUNCT      ,          punct
# and             CCONJ      CC         cc
# ethicists       NOUN       NNS        conj
# is              AUX        VBZ        ROOT
# necessary       ADJ        JJ         acomp
# to              PART       TO         aux
# address         VERB       VB         xcomp
# the             DET        DT         det
# challenges      NOUN       NNS        dobj
# and             CCONJ      CC         cc
# maximize        VERB       VB         conj
# the             DET        DT         det
# benefits        NOUN       NNS        dobj
# of              ADP        IN         prep
# AI              PROPN      NNP        pobj
# .               PUNCT      .          punct
# Rather          ADV        RB         advmod
# than            ADP        IN         prep
# replacing       VERB       VBG        pcomp
# humans          NOUN       NNS        dobj
# ,               PUNCT      ,          punct
# AI              PROPN      NNP        nsubj
# has             VERB       VBZ        ROOT
# the             DET        DT         det
# potential       NOUN       NN         dobj
# to              PART       TO         aux
# augment         VERB       VB         acl
# human           ADJ        JJ         amod
# capabilities    NOUN       NNS        dobj
# ,               PUNCT      ,          punct
# enabling        VERB       VBG        advcl
# better          ADJ        JJR        amod
# decision        NOUN       NN         compound
# -               PUNCT      HYPH       punct
# making          NOUN       NN         dobj
# ,               PUNCT      ,          punct
# creativity      NOUN       NN         conj
# ,               PUNCT      ,          punct
# and             CCONJ      CC         cc
# problem         NOUN       NN         compound
# -               PUNCT      HYPH       punct
# solving         NOUN       NN         conj
# .               PUNCT      .          punct
#
#
#               SPACE      _SP        dep
# In              ADP        IN         prep
# conclusion      NOUN       NN         pobj
# ,               PUNCT      ,          punct
# artificial      ADJ        JJ         amod
# intelligence    NOUN       NN         nsubj
# is              AUX        VBZ        ROOT
# a               DET        DT         det
# powerful        ADJ        JJ         amod
# tool            NOUN       NN         attr
# that            PRON       WDT        nsubj
# is              AUX        VBZ        aux
# reshaping       VERB       VBG        relcl
# modern          ADJ        JJ         amod
# society         NOUN       NN         dobj
# in              ADP        IN         prep
# profound        ADJ        JJ         amod
# ways            NOUN       NNS        pobj
# .               PUNCT      .          punct
# Its             PRON       PRP$       poss
# applications    NOUN       NNS        nsubj
# span            VERB       VBP        ROOT
# multiple        ADJ        JJ         amod
# domains         NOUN       NNS        dobj
# ,               PUNCT      ,          punct
# offering        VERB       VBG        advcl
# solutions       NOUN       NNS        dobj
# to              ADP        IN         prep
# complex         ADJ        JJ         amod
# problems        NOUN       NNS        pobj
# while           SCONJ      IN         mark
# also            ADV        RB         advmod
# introducing     VERB       VBG        advcl
# new             ADJ        JJ         amod
# risks           NOUN       NNS        dobj
# and             CCONJ      CC         cc
# ethical         ADJ        JJ         amod
# dilemmas        NOUN       NNS        conj
# .               PUNCT      .          punct
# Understanding   VERB       VBG        compound
# AI              PROPN      NNP        poss
# ’s              PART       POS        case
# capabilities    NOUN       NNS        nsubj
# and             CCONJ      CC         cc
# limitations     NOUN       NNS        conj
# is              AUX        VBZ        ROOT
# essential       ADJ        JJ         acomp
# for             ADP        IN         prep
# responsible     ADJ        JJ         amod
# use             NOUN       NN         pobj
# .               PUNCT      .          punct
# As              SCONJ      IN         mark
# AI              PROPN      NNP        nsubj
# continues       VERB       VBZ        advcl
# to              PART       TO         aux
# evolve          VERB       VB         xcomp
# ,               PUNCT      ,          punct
# its             PRON       PRP$       poss
# impact          NOUN       NN         nsubjpass
# will            AUX        MD         aux
# be              AUX        VB         auxpass
# determined      VERB       VBN        ROOT
# not             PART       RB         preconj
# only            ADV        RB         advmod
# by              ADP        IN         agent
# technological   ADJ        JJ         amod
# advancements    NOUN       NNS        pobj
# but             CCONJ      CC         cc
# also            ADV        RB         advmod
# by              ADP        IN         conj
# the             DET        DT         det
# values          NOUN       NNS        pobj
# and             CCONJ      CC         cc
# choices         NOUN       NNS        conj
# of              ADP        IN         prep
# the             DET        DT         det
# people          NOUN       NNS        pobj
# who             PRON       WP         nsubj
# develop         VERB       VBP        relcl
# and             CCONJ      CC         cc
# deploy          VERB       VB         conj
# it              PRON       PRP        dobj
# .               PUNCT      .          punct
#
#                SPACE      _SP        dep

# %% [markdown]
# | Column       | Meaning             |
# | ------------ | ------------------- |
# | `token.text` | Actual word    |
# | `pos_`       | Universal POS tag   |
# | `tag_`       | Detailed POS tag    |
# | `dep_`       | Dependency relation |

# %% [markdown]
# ## **POS Tag Frequency Analysis**

# %%
from collections import Counter

# %%
pos_counts = Counter([token.pos_ for token in doc])

print(pos_counts)
# Out:
# Counter({'NOUN': 171, 'VERB': 88, 'PUNCT': 86, 'ADJ': 64, 'ADP': 61, 'CCONJ': 32, 'AUX': 25, 'DET': 24, 'ADV': 23, 'PROPN': 21, 'PART': 15, 'PRON': 11, 'SCONJ': 10, 'SPACE': 7, 'NUM': 3})

# %% [markdown]
# This helps analyze:
#
# *  Noun density
#
# *  Verb usage
#
# *  Sentence complexity

# %% [markdown]
# ## **Dependency Parsing (Syntactic Structure)**
#
# **Sentence-wise Dependency Analysis**

# %%
for sent in doc.sents:
    print(f"\nSentence: {sent}")
    for token in sent:
        print(f"{token.text:<12} --> {token.head.text:<12} ({token.dep_})")
# Out:
# Sentence: Artificial Intelligence (AI) has emerged as one of the most transformative technologies of the twenty-first century.
# Artificial   --> Intelligence (compound)
# Intelligence --> emerged      (nsubj)
# (            --> Intelligence (punct)
# AI           --> Intelligence (appos)
# )            --> Intelligence (punct)
# has          --> emerged      (aux)
# emerged      --> emerged      (ROOT)
# as           --> emerged      (prep)
# one          --> as           (pobj)
# of           --> one          (prep)
# the          --> technologies (det)
# most         --> transformative (advmod)
# transformative --> technologies (amod)
# technologies --> of           (pobj)
# of           --> technologies (prep)
# the          --> century      (det)
# twenty       --> first        (advmod)
# -            --> first        (punct)
# first        --> century      (amod)
# century      --> of           (pobj)
# .            --> emerged      (punct)
#
# Sentence: From simple rule-based systems to complex deep learning architectures, AI has evolved rapidly and is now deeply integrated into many aspects of daily life.
# From         --> evolved      (prep)
# simple       --> systems      (amod)
# rule         --> based        (npadvmod)
# -            --> based        (punct)
# based        --> systems      (amod)
# systems      --> From         (pobj)
# to           --> From         (prep)
# complex      --> learning     (amod)
# deep         --> learning     (amod)
# learning     --> to           (pobj)
# architectures --> From         (pobj)
# ,            --> evolved      (punct)
# AI           --> evolved      (nsubj)
# has          --> evolved      (aux)
# evolved      --> evolved      (ROOT)
# rapidly      --> evolved      (advmod)
# and          --> evolved      (cc)
# is           --> integrated   (auxpass)
# now          --> integrated   (advmod)
# deeply       --> integrated   (advmod)
# integrated   --> evolved      (conj)
# into         --> integrated   (prep)
# many         --> aspects      (amod)
# aspects      --> into         (pobj)
# of           --> aspects      (prep)
# daily        --> life         (amod)
# life         --> of           (pobj)
# .            --> evolved      (punct)
#
# Sentence: Its influence can be seen across industries such as healthcare, education, finance, transportation, and entertainment.
# Its          --> influence    (poss)
# influence    --> seen         (nsubjpass)
# can          --> seen         (aux)
# be           --> seen         (auxpass)
# seen         --> seen         (ROOT)
# across       --> seen         (prep)
# industries   --> across       (pobj)
# such         --> as           (amod)
# as           --> industries   (prep)
# healthcare   --> as           (pobj)
# ,            --> healthcare   (punct)
# education    --> healthcare   (conj)
# ,            --> education    (punct)
# finance      --> education    (conj)
# ,            --> finance      (punct)
# transportation --> finance      (conj)
# ,            --> transportation (punct)
# and          --> transportation (cc)
# entertainment --> transportation (conj)
# .            --> seen         (punct)
#
# Sentence: As AI systems continue to grow in capability and adoption, they are reshaping how humans work, communicate, and make decisions.
#
#
# As           --> continue     (mark)
# AI           --> systems      (compound)
# systems      --> continue     (nsubj)
# continue     --> reshaping    (advcl)
# to           --> grow         (aux)
# grow         --> continue     (xcomp)
# in           --> grow         (prep)
# capability   --> in           (pobj)
# and          --> capability   (cc)
# adoption     --> capability   (conj)
# ,            --> reshaping    (punct)
# they         --> reshaping    (nsubj)
# are          --> reshaping    (aux)
# reshaping    --> reshaping    (ROOT)
# how          --> work         (advmod)
# humans       --> work         (nsubj)
# work         --> reshaping    (ccomp)
# ,            --> work         (punct)
# communicate  --> work         (conj)
# ,            --> communicate  (punct)
# and          --> communicate  (cc)
# make         --> communicate  (conj)
# decisions    --> make         (dobj)
# .            --> reshaping    (punct)
#
#
#            --> .            (dep)
#
# Sentence: At its core, artificial intelligence refers to the ability of machines to simulate human intelligence.
# At           --> refers       (prep)
# its          --> core         (poss)
# core         --> At           (pobj)
# ,            --> refers       (punct)
# artificial   --> intelligence (amod)
# intelligence --> refers       (nsubj)
# refers       --> refers       (ROOT)
# to           --> refers       (prep)
# the          --> ability      (det)
# ability      --> to           (pobj)
# of           --> ability      (prep)
# machines     --> of           (pobj)
# to           --> simulate     (aux)
# simulate     --> ability      (acl)
# human        --> intelligence (amod)
# intelligence --> simulate     (dobj)
# .            --> refers       (punct)
#
# Sentence: This includes learning from data, recognizing patterns, understanding language, and making decisions with minimal human intervention.
# This         --> includes     (nsubj)
# includes     --> includes     (ROOT)
# learning     --> includes     (xcomp)
# from         --> learning     (prep)
# data         --> from         (pobj)
# ,            --> learning     (punct)
# recognizing  --> learning     (advcl)
# patterns     --> recognizing  (dobj)
# ,            --> patterns     (punct)
# understanding --> patterns     (acl)
# language     --> understanding (dobj)
# ,            --> understanding (punct)
# and          --> understanding (cc)
# making       --> understanding (conj)
# decisions    --> making       (dobj)
# with         --> decisions    (prep)
# minimal      --> intervention (amod)
# human        --> intervention (amod)
# intervention --> with         (pobj)
# .            --> includes     (punct)
#
# Sentence: Early AI systems were limited in scope and required explicit programming.
# Early        --> systems      (amod)
# AI           --> systems      (compound)
# systems      --> limited      (nsubjpass)
# were         --> limited      (auxpass)
# limited      --> limited      (ROOT)
# in           --> limited      (prep)
# scope        --> in           (pobj)
# and          --> limited      (cc)
# required     --> limited      (conj)
# explicit     --> programming  (amod)
# programming  --> required     (dobj)
# .            --> limited      (punct)
#
# Sentence: However, modern AI relies heavily on machine learning and deep learning techniques, enabling systems to improve automatically through experience.
# However      --> relies       (advmod)
# ,            --> relies       (punct)
# modern       --> AI           (amod)
# AI           --> relies       (nsubj)
# relies       --> relies       (ROOT)
# heavily      --> relies       (advmod)
# on           --> relies       (prep)
# machine      --> learning     (compound)
# learning     --> on           (pobj)
# and          --> learning     (cc)
# deep         --> learning     (amod)
# learning     --> techniques   (compound)
# techniques   --> learning     (conj)
# ,            --> relies       (punct)
# enabling     --> relies       (advcl)
# systems      --> enabling     (dobj)
# to           --> improve      (aux)
# improve      --> enabling     (xcomp)
# automatically --> improve      (advmod)
# through      --> improve      (prep)
# experience   --> through      (pobj)
# .            --> relies       (punct)
#
# Sentence: The availability of large datasets, increased computational power, and advanced algorithms has accelerated this progress significantly.
#
#
# The          --> availability (det)
# availability --> increased    (nsubj)
# of           --> availability (prep)
# large        --> datasets     (amod)
# datasets     --> of           (pobj)
# ,            --> availability (punct)
# increased    --> increased    (ROOT)
# computational --> power        (amod)
# power        --> increased    (dobj)
# ,            --> increased    (punct)
# and          --> increased    (cc)
# advanced     --> algorithms   (amod)
# algorithms   --> accelerated  (nsubj)
# has          --> accelerated  (aux)
# accelerated  --> increased    (conj)
# this         --> progress     (det)
# progress     --> accelerated  (dobj)
# significantly --> accelerated  (advmod)
# .            --> accelerated  (punct)
#
#
#            --> .            (dep)
#
# Sentence: One of the most impactful applications of AI is in healthcare.
# One          --> is           (nsubj)
# of           --> One          (prep)
# the          --> applications (det)
# most         --> impactful    (advmod)
# impactful    --> applications (amod)
# applications --> of           (pobj)
# of           --> applications (prep)
# AI           --> of           (pobj)
# is           --> is           (ROOT)
# in           --> is           (prep)
# healthcare   --> in           (pobj)
# .            --> is           (punct)
#
# Sentence: AI-powered systems are now used to assist doctors in diagnosing diseases, predicting patient outcomes, and personalizing treatment plans.
# AI           --> powered      (npadvmod)
# -            --> powered      (punct)
# powered      --> systems      (amod)
# systems      --> used         (nsubjpass)
# are          --> used         (auxpass)
# now          --> used         (advmod)
# used         --> used         (ROOT)
# to           --> assist       (aux)
# assist       --> used         (xcomp)
# doctors      --> assist       (dobj)
# in           --> assist       (prep)
# diagnosing   --> in           (pcomp)
# diseases     --> diagnosing   (dobj)
# ,            --> assist       (punct)
# predicting   --> assist       (advcl)
# patient      --> outcomes     (amod)
# outcomes     --> predicting   (dobj)
# ,            --> predicting   (punct)
# and          --> predicting   (cc)
# personalizing --> predicting   (conj)
# treatment    --> plans        (compound)
# plans        --> personalizing (dobj)
# .            --> used         (punct)
#
# Sentence: For example, machine learning models can analyze medical images such as X-rays and MRIs with high accuracy, often matching or exceeding human performance.
# For          --> analyze      (prep)
# example      --> For          (pobj)
# ,            --> analyze      (punct)
# machine      --> learning     (compound)
# learning     --> models       (compound)
# models       --> analyze      (nsubj)
# can          --> analyze      (aux)
# analyze      --> analyze      (ROOT)
# medical      --> images       (amod)
# images       --> analyze      (dobj)
# such         --> as           (amod)
# as           --> images       (prep)
# X            --> as           (pobj)
# -            --> as           (pobj)
# rays         --> as           (pobj)
# and          --> rays         (cc)
# MRIs         --> rays         (conj)
# with         --> analyze      (prep)
# high         --> accuracy     (amod)
# accuracy     --> with         (pobj)
# ,            --> analyze      (punct)
# often        --> matching     (advmod)
# matching     --> analyze      (advcl)
# or           --> matching     (cc)
# exceeding    --> matching     (conj)
# human        --> performance  (amod)
# performance  --> exceeding    (dobj)
# .            --> analyze      (punct)
#
# Sentence: AI also plays a crucial role in drug discovery by analyzing chemical compounds and predicting their effectiveness, reducing both time and cost.
# AI           --> plays        (nsubj)
# also         --> plays        (advmod)
# plays        --> plays        (ROOT)
# a            --> role         (det)
# crucial      --> role         (amod)
# role         --> plays        (dobj)
# in           --> role         (prep)
# drug         --> discovery    (compound)
# discovery    --> in           (pobj)
# by           --> plays        (prep)
# analyzing    --> by           (pcomp)
# chemical     --> compounds    (compound)
# compounds    --> analyzing    (dobj)
# and          --> analyzing    (cc)
# predicting   --> analyzing    (conj)
# their        --> effectiveness (poss)
# effectiveness --> predicting   (dobj)
# ,            --> predicting   (punct)
# reducing     --> predicting   (advcl)
# both         --> time         (det)
# time         --> reducing     (dobj)
# and          --> time         (cc)
# cost         --> time         (conj)
# .            --> plays        (punct)
#
# Sentence: Despite these benefits, concerns remain regarding data privacy, bias in medical datasets, and the need for human oversight in critical healthcare decisions.
#
#
# Despite      --> remain       (prep)
# these        --> benefits     (det)
# benefits     --> Despite      (pobj)
# ,            --> remain       (punct)
# concerns     --> remain       (nsubj)
# remain       --> remain       (ROOT)
# regarding    --> remain       (prep)
# data         --> privacy      (compound)
# privacy      --> regarding    (pobj)
# ,            --> privacy      (punct)
# bias         --> privacy      (conj)
# in           --> bias         (prep)
# medical      --> datasets     (amod)
# datasets     --> in           (pobj)
# ,            --> bias         (punct)
# and          --> bias         (cc)
# the          --> need         (det)
# need         --> bias         (conj)
# for          --> need         (prep)
# human        --> oversight    (amod)
# oversight    --> for          (pobj)
# in           --> oversight    (prep)
# critical     --> decisions    (amod)
# healthcare   --> decisions    (compound)
# decisions    --> in           (pobj)
# .            --> remain       (punct)
#
#
#            --> .            (dep)
#
# Sentence: In the field of education, AI is transforming traditional learning methods.
# In           --> transforming (prep)
# the          --> field        (det)
# field        --> In           (pobj)
# of           --> field        (prep)
# education    --> of           (pobj)
# ,            --> transforming (punct)
# AI           --> transforming (nsubj)
# is           --> transforming (aux)
# transforming --> transforming (ROOT)
# traditional  --> methods      (amod)
# learning     --> methods      (compound)
# methods      --> transforming (dobj)
# .            --> transforming (punct)
#
# Sentence: Intelligent tutoring systems can adapt content based on a student’s learning pace, strengths, and weaknesses.
# Intelligent  --> systems      (amod)
# tutoring     --> systems      (compound)
# systems      --> adapt        (nsubj)
# can          --> adapt        (aux)
# adapt        --> adapt        (ROOT)
# content      --> adapt        (dobj)
# based        --> adapt        (prep)
# on           --> based        (prep)
# a            --> pace         (det)
# student      --> learning     (npadvmod)
# ’s           --> student      (case)
# learning     --> pace         (compound)
# pace         --> on           (pobj)
# ,            --> pace         (punct)
# strengths    --> pace         (conj)
# ,            --> strengths    (punct)
# and          --> strengths    (cc)
# weaknesses   --> strengths    (conj)
# .            --> adapt        (punct)
#
# Sentence: Online learning platforms use recommendation algorithms to suggest courses and resources tailored to individual needs.
# Online       --> learning     (amod)
# learning     --> platforms    (compound)
# platforms    --> use          (nsubj)
# use          --> use          (ROOT)
# recommendation --> algorithms   (compound)
# algorithms   --> use          (dobj)
# to           --> suggest      (aux)
# suggest      --> use          (xcomp)
# courses      --> suggest      (dobj)
# and          --> courses      (cc)
# resources    --> courses      (conj)
# tailored     --> courses      (acl)
# to           --> tailored     (prep)
# individual   --> needs        (amod)
# needs        --> to           (pobj)
# .            --> use          (punct)
#
# Sentence: Automated grading systems help educators save time while providing consistent evaluation.
# Automated    --> systems      (amod)
# grading      --> systems      (compound)
# systems      --> help         (nsubj)
# help         --> help         (ROOT)
# educators    --> save         (nsubj)
# save         --> help         (ccomp)
# time         --> save         (dobj)
# while        --> providing    (mark)
# providing    --> save         (advcl)
# consistent   --> evaluation   (amod)
# evaluation   --> providing    (dobj)
# .            --> help         (punct)
#
# Sentence: However, over-reliance on AI in education raises questions about reduced human interaction, unequal access to technology, and the potential loss of critical thinking skills if students depend too heavily on automated assistance.
#
#
# However      --> raises       (advmod)
# ,            --> raises       (punct)
# over         --> raises       (nsubj)
# -            --> over         (punct)
# reliance     --> over         (pobj)
# on           --> over         (prep)
# AI           --> on           (pobj)
# in           --> over         (prep)
# education    --> in           (pobj)
# raises       --> raises       (ROOT)
# questions    --> raises       (dobj)
# about        --> questions    (prep)
# reduced      --> interaction  (amod)
# human        --> interaction  (amod)
# interaction  --> about        (pobj)
# ,            --> raises       (punct)
# unequal      --> access       (amod)
# access       --> ,            (prep)
# to           --> access       (prep)
# technology   --> to           (pobj)
# ,            --> access       (punct)
# and          --> access       (cc)
# the          --> loss         (det)
# potential    --> loss         (amod)
# loss         --> access       (conj)
# of           --> loss         (prep)
# critical     --> skills       (amod)
# thinking     --> skills       (compound)
# skills       --> of           (pobj)
# if           --> depend       (mark)
# students     --> depend       (nsubj)
# depend       --> raises       (advcl)
# too          --> heavily      (advmod)
# heavily      --> depend       (advmod)
# on           --> depend       (prep)
# automated    --> assistance   (amod)
# assistance   --> on           (pobj)
# .            --> raises       (punct)
#
#
#            --> .            (dep)
#
# Sentence: Data privacy and security are also critical issues in the AI era.
# Data         --> privacy      (compound)
# privacy      --> are          (nsubj)
# and          --> privacy      (cc)
# security     --> privacy      (conj)
# are          --> are          (ROOT)
# also         --> are          (advmod)
# critical     --> issues       (amod)
# issues       --> are          (attr)
# in           --> issues       (prep)
# the          --> era          (det)
# AI           --> era          (compound)
# era          --> in           (pobj)
# .            --> are          (punct)
#
# Sentence: AI systems rely on vast amounts of data, much of which is personal or sensitive.
# AI           --> systems      (compound)
# systems      --> rely         (nsubj)
# rely         --> rely         (ROOT)
# on           --> rely         (prep)
# vast         --> amounts      (amod)
# amounts      --> on           (pobj)
# of           --> amounts      (prep)
# data         --> of           (pobj)
# ,            --> data         (punct)
# much         --> is           (nsubj)
# of           --> much         (prep)
# which        --> of           (pobj)
# is           --> amounts      (relcl)
# personal     --> is           (acomp)
# or           --> personal     (cc)
# sensitive    --> personal     (conj)
# .            --> rely         (punct)
#
# Sentence: Ensuring that data is collected, stored, and used responsibly is essential to maintaining public trust.
# Ensuring     --> is           (advcl)
# that         --> collected    (mark)
# data         --> collected    (nsubjpass)
# is           --> collected    (auxpass)
# collected    --> Ensuring     (ccomp)
# ,            --> collected    (punct)
# stored       --> collected    (conj)
# ,            --> collected    (punct)
# and          --> collected    (cc)
# used         --> is           (csubj)
# responsibly  --> used         (advmod)
# is           --> is           (ROOT)
# essential    --> is           (acomp)
# to           --> essential    (prep)
# maintaining  --> to           (pcomp)
# public       --> trust        (amod)
# trust        --> maintaining  (dobj)
# .            --> is           (punct)
#
# Sentence: Governments and organizations worldwide are developing regulations and ethical guidelines to govern AI development and deployment.
# Governments  --> developing   (nsubj)
# and          --> Governments  (cc)
# organizations --> Governments  (conj)
# worldwide    --> Governments  (advmod)
# are          --> developing   (aux)
# developing   --> developing   (ROOT)
# regulations  --> developing   (dobj)
# and          --> regulations  (cc)
# ethical      --> guidelines   (amod)
# guidelines   --> regulations  (conj)
# to           --> govern       (aux)
# govern       --> regulations  (acl)
# AI           --> development  (compound)
# development  --> govern       (dobj)
# and          --> development  (cc)
# deployment   --> development  (conj)
# .            --> developing   (punct)
#
# Sentence: These efforts aim to balance innovation with responsibility, ensuring that AI benefits society as a whole.
#
#
# These        --> efforts      (det)
# efforts      --> aim          (nsubj)
# aim          --> aim          (ROOT)
# to           --> balance      (aux)
# balance      --> aim          (xcomp)
# innovation   --> balance      (dobj)
# with         --> balance      (prep)
# responsibility --> with         (pobj)
# ,            --> aim          (punct)
# ensuring     --> aim          (advcl)
# that         --> society      (mark)
# AI           --> benefits     (nsubj)
# benefits     --> society      (compound)
# society      --> ensuring     (dobj)
# as           --> society      (prep)
# a            --> whole        (det)
# whole        --> as           (pobj)
# .            --> aim          (punct)
#
#
#            --> .            (dep)
#
# Sentence: Looking ahead, the future of artificial intelligence will depend on how humans choose to design, regulate, and interact with these systems.
# Looking      --> depend       (advcl)
# ahead        --> Looking      (advmod)
# ,            --> depend       (punct)
# the          --> future       (det)
# future       --> depend       (nsubj)
# of           --> future       (prep)
# artificial   --> intelligence (amod)
# intelligence --> of           (pobj)
# will         --> depend       (aux)
# depend       --> depend       (ROOT)
# on           --> depend       (prep)
# how          --> design       (advmod)
# humans       --> choose       (nsubj)
# choose       --> on           (pcomp)
# to           --> design       (aux)
# design       --> choose       (xcomp)
# ,            --> design       (punct)
# regulate     --> design       (conj)
# ,            --> regulate     (punct)
# and          --> regulate     (cc)
# interact     --> regulate     (conj)
# with         --> interact     (prep)
# these        --> systems      (det)
# systems      --> with         (pobj)
# .            --> depend       (punct)
#
# Sentence: Collaboration between technologists, policymakers, educators, and ethicists is necessary to address the challenges and maximize the benefits of AI.
# Collaboration --> is           (nsubj)
# between      --> Collaboration (prep)
# technologists --> between      (pobj)
# ,            --> technologists (punct)
# policymakers --> technologists (conj)
# ,            --> policymakers (punct)
# educators    --> policymakers (conj)
# ,            --> educators    (punct)
# and          --> educators    (cc)
# ethicists    --> educators    (conj)
# is           --> is           (ROOT)
# necessary    --> is           (acomp)
# to           --> address      (aux)
# address      --> necessary    (xcomp)
# the          --> challenges   (det)
# challenges   --> address      (dobj)
# and          --> address      (cc)
# maximize     --> address      (conj)
# the          --> benefits     (det)
# benefits     --> maximize     (dobj)
# of           --> benefits     (prep)
# AI           --> of           (pobj)
# .            --> is           (punct)
#
# Sentence: Rather than replacing humans, AI has the potential to augment human capabilities, enabling better decision-making, creativity, and problem-solving.
#
#
# Rather       --> than         (advmod)
# than         --> has          (prep)
# replacing    --> than         (pcomp)
# humans       --> replacing    (dobj)
# ,            --> has          (punct)
# AI           --> has          (nsubj)
# has          --> has          (ROOT)
# the          --> potential    (det)
# potential    --> has          (dobj)
# to           --> augment      (aux)
# augment      --> potential    (acl)
# human        --> capabilities (amod)
# capabilities --> augment      (dobj)
# ,            --> has          (punct)
# enabling     --> has          (advcl)
# better       --> making       (amod)
# decision     --> making       (compound)
# -            --> making       (punct)
# making       --> enabling     (dobj)
# ,            --> making       (punct)
# creativity   --> making       (conj)
# ,            --> creativity   (punct)
# and          --> creativity   (cc)
# problem      --> solving      (compound)
# -            --> solving      (punct)
# solving      --> creativity   (conj)
# .            --> has          (punct)
#
#
#            --> .            (dep)
#
# Sentence: In conclusion, artificial intelligence is a powerful tool that is reshaping modern society in profound ways.
# In           --> is           (prep)
# conclusion   --> In           (pobj)
# ,            --> is           (punct)
# artificial   --> intelligence (amod)
# intelligence --> is           (nsubj)
# is           --> is           (ROOT)
# a            --> tool         (det)
# powerful     --> tool         (amod)
# tool         --> is           (attr)
# that         --> reshaping    (nsubj)
# is           --> reshaping    (aux)
# reshaping    --> tool         (relcl)
# modern       --> society      (amod)
# society      --> reshaping    (dobj)
# in           --> reshaping    (prep)
# profound     --> ways         (amod)
# ways         --> in           (pobj)
# .            --> is           (punct)
#
# Sentence: Its applications span multiple domains, offering solutions to complex problems while also introducing new risks and ethical dilemmas.
# Its          --> applications (poss)
# applications --> span         (nsubj)
# span         --> span         (ROOT)
# multiple     --> domains      (amod)
# domains      --> span         (dobj)
# ,            --> span         (punct)
# offering     --> span         (advcl)
# solutions    --> offering     (dobj)
# to           --> offering     (prep)
# complex      --> problems     (amod)
# problems     --> to           (pobj)
# while        --> introducing  (mark)
# also         --> introducing  (advmod)
# introducing  --> offering     (advcl)
# new          --> risks        (amod)
# risks        --> introducing  (dobj)
# and          --> risks        (cc)
# ethical      --> dilemmas     (amod)
# dilemmas     --> risks        (conj)
# .            --> span         (punct)
#
# Sentence: Understanding AI’s capabilities and limitations is essential for responsible use.
# Understanding --> AI           (compound)
# AI           --> capabilities (poss)
# ’s           --> AI           (case)
# capabilities --> is           (nsubj)
# and          --> capabilities (cc)
# limitations  --> capabilities (conj)
# is           --> is           (ROOT)
# essential    --> is           (acomp)
# for          --> essential    (prep)
# responsible  --> use          (amod)
# use          --> for          (pobj)
# .            --> is           (punct)
#
# Sentence: As AI continues to evolve, its impact will be determined not only by technological advancements but also by the values and choices of the people who develop and deploy it.
#
# As           --> continues    (mark)
# AI           --> continues    (nsubj)
# continues    --> determined   (advcl)
# to           --> evolve       (aux)
# evolve       --> continues    (xcomp)
# ,            --> determined   (punct)
# its          --> impact       (poss)
# impact       --> determined   (nsubjpass)
# will         --> determined   (aux)
# be           --> determined   (auxpass)
# determined   --> determined   (ROOT)
# not          --> by           (preconj)
# only         --> not          (advmod)
# by           --> determined   (agent)
# technological --> advancements (amod)
# advancements --> by           (pobj)
# but          --> by           (cc)
# also         --> but          (advmod)
# by           --> by           (conj)
# the          --> values       (det)
# values       --> by           (pobj)
# and          --> values       (cc)
# choices      --> values       (conj)
# of           --> values       (prep)
# the          --> people       (det)
# people       --> of           (pobj)
# who          --> develop      (nsubj)
# develop      --> people       (relcl)
# and          --> develop      (cc)
# deploy       --> develop      (conj)
# it           --> deploy       (dobj)
# .            --> determined   (punct)
#
#             --> .            (dep)

# %% [markdown]
# In this:
#
# *  Head word of each token
#
# *  Grammatical relationship
#
# *  Sentence structure flow

# %% [markdown]
# ### **Single Sentence Dependency Tree Visualization**

# %%
sentence = list(doc.sents)[0]
displacy.render(sentence, style="dep", jupyter=True, options={'distance': 110})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="a2718a3ff4d54419ba2bb6b1760ab249-0" class="displacy" width="1920" height="302.0" direction="ltr" style="max-width: none; height: 302.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Artificial</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="160">Intelligence (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="160">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="270">AI)</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="270">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="380">has</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="380">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="490">emerged</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="490">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="600">as</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="600">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="710">one</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="710">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="820">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="820">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">most</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">transformative</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="1260">technologies</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1260">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="1480">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1480">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="1590">twenty-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1590">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">first</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="212.0">
#     <tspan class="displacy-word" fill="currentColor" x="1810">century.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1810">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a2718a3ff4d54419ba2bb6b1760ab249-0-0" stroke-width="2px" d="M70,167.0 C70,112.0 150.0,112.0 150.0,167.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a2718a3ff4d54419ba2bb6b1760ab249-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,169.0 L62,157.0 78,157.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a2718a3ff4d54419ba2bb6b1760ab249-0-1" stroke-width="2px" d="M180,167.0 C180,57.0 485.0,57.0 485.0,167.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a2718a3ff4d54419ba2bb6b1760ab249-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M180,169.0 L172,157.0 188,157.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a2718a3ff4d54419ba2bb6b1760ab249-0-2" stroke-width="2px" d="M180,167.0 C180,112.0 260.0,112.0 260.0,167.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a2718a3ff4d54419ba2bb6b1760ab249-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">appos</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M260.0,169.0 L268.0,157.0 252.0,157.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a2718a3ff4d54419ba2bb6b1760ab249-0-3" stroke-width="2px" d="M400,167.0 C400,112.0 480.0,112.0 480.0,167.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a2718a3ff4d54419ba2bb6b1760ab249-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">aux</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M400,169.0 L392,157.0 408,157.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a2718a3ff4d54419ba2bb6b1760ab249-0-4" stroke-width="2px" d="M510,167.0 C510,112.0 590.0,112.0 590.0,167.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a2718a3ff4d54419ba2bb6b1760ab249-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">prep</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M590.0,169.0 L598.0,157.0 582.0,157.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-a2718a3ff4d54419ba2bb6b1760ab249-0-5" stroke-width="2px" d="M620,167.0 C620,112.0 700.0,112.0 700.0,167.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-a2718a3ff4d54419ba2bb6b1760ab249-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">pobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M700.0,169.0 L708.0

# %% [markdown]
# ### **All Sentence Dependency Tree Visualization**

# %%
from spacy import displacy

displacy.render(doc, style="dep", jupyter=True, options={'distance': 110})
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="a6ffb6360596433bb4c488c7b91627ec-0" class="displacy" width="60990" height="467.0" direction="ltr" style="max-width: none; height: 467.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Artificial</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="160">Intelligence (</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="160">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="270">AI)</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="270">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="380">has</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="380">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="490">emerged</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="490">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="600">as</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="600">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="710">one</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="710">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="820">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="820">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="930">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="930">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">most</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">ADV</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="1150">transformative</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1150">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="1260">technologies</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1260">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="1370">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1370">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="1480">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1480">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="1590">twenty-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1590">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">first</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="1810">century.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1810">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="1920">From</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1920">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="2030">simple</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2030">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="2140">rule-</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2140">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="2250">based</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2250">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="2360">systems</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2360">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="2470">to</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2470">PART</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="2580">complex</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2580">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="2690">deep</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2690">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="2800">learning</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2800">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="2910">architectures,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2910">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="3020">AI</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3020">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="3130">has</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3130">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="3240">evolved</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3240">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="377.0">
#     <tspan class="displacy-word" fill="currentColor" x="3350">rapidly</tspan>
#     <tspan class="displacy-tag" dy

# %% [markdown]
# Key Components in the Visualization
#
# > Tokens (Words)
#
# * Displayed horizontally in the order they appear in the sentence.
#
# * Each token represents a single word.
#
# > ROOT
#
# * The main verb of the sentence.
#
# * Acts as the central node.
#
# * All other words are directly or indirectly connected to the ROOT.
#
# Example:
#
# > transforming → ROOT

# %% [markdown]
# options={'distance': 110})

# %% [markdown]
# ## **Conclusion**
#
# In this project, POS tagging and dependency parsing were successfully applied to a text corpus to analyze its grammatical structure. POS tagging provided word-level grammatical information, while dependency parsing offered deeper insights into syntactic relationships such as subject, object, and modifiers. The dependency tree visualization helped clearly illustrate these relationships in a structured and interpretable manner. Overall, this approach enhances the understanding of sentence structure and forms a strong foundation for advanced NLP tasks such as information extraction, question answering, and machine translation.
